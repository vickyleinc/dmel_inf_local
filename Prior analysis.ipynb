# %%
import csv
import os
import scipy.io
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np
import pandas as pd

# %%
with open('/Users/vickyle/Desktop/priors.tsv') as data:
    data2 = pd.read_csv(data, sep='\t')
    plt.figure(figsize=(30, 30))
    cmap = sns.cm.rocket_r
    ax = sns.heatmap(data2,
                 annot=False,
                 cmap = cmap)

# %%
data2.sum(axis=0).hist(bins=200)

# %%
data2.shape
# Out:
# (17300, 316)

# %%
#combined prior

# %%
with open('/Users/vickyle/Desktop/priors.tsv') as combined:
    combined_table = pd.read_csv(combined, sep='\t')
    plt.figure(figsize=(30, 30))
    cmap = sns.cm.rocket_r
    ax = sns.heatmap(combined_table,
                 annot=False,
                 cmap = cmap)

# %%
combined_table.sum(axis=0).hist(bins=200)
